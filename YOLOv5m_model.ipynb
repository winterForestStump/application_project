# %% [markdown]
# <a href="https://colab.research.google.com/github/winterForestStump/application_project/blob/main/YOLOv5m_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cloning the YOLOv5 model:

# %%
path_clone = "path/where/to/clone/the/model"
!%cd 'path'

# %%
# !git clone https://github.com/ultralytics/yolov5.git "/path/where/to/clone/the/model"

# %%
# !cd "/path/where/to/clone/the/model"

# %%
#installing requirements
# !pip install -r requirements.txt

# %% [markdown]
# If necessary, run Comet to visualize the results of training. Otherwise use Tensorboard

# %%
logger = 'Comet' #@param ['TensorBoard']

if logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# COMET INFO: Valid Comet API Key saved in C:\Users\lenovo\.comet.config (set COMET_CONFIG to change where it is saved).

# %% [markdown]
# # Training the model

# %% [markdown]
# * Medium size - YOLOv5m
# * Batch - 16
# * Epochs - 100
# * Device - 0 (gpu)

# %%
# !python "/path/where/to/clone/the/model"/model/train.py --img 640 --batch 16 --epochs 100 --data "/path/where/to/clone/the/model"/ready_data.yaml --weights yolov5m.pt --cache --device 0 --workers 2
# Out:
# requirements: YOLOv5 requirement "gitpython" not found, attempting AutoUpdate...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.9 MB/s eta 0:00:00
# ...
#
# requirements: 1 package updated per ['gitpython']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...

# %% [markdown]
# # Testing the model

# %%
# !python "/path/where/to/clone/the/model"/model/val.py --weights "/path/where/to/clone/the/model"/model/runs/train/exp3/weights/best.pt --img 640 --data "/path/where/to/clone/the/model"/ready_data.yaml --task test
# Out:
# val: data=C:/Users/lenovo/python/FH_Kiel_DS/2_semester/Application_Project/PROJECT/ready_data.yaml, weights=['C:/Users/lenovo/python/FH_Kiel_DS/2_semester/Application_Project/PROJECT/model/runs/train/exp3/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=model\runs\val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5  v7.0-165-ge382d4c Python-3.11.2 torch-2.0.0+cpu CPU
#
# Fusing layers...
# Model summary: 212 layers, 20897385 parameters, 0 gradients, 48.0 GFLOPs
#
# test: Scanning C:\Users\lenovo\python\FH_Kiel_DS\2_semester\Application_Project\PROJECT\test_data\labels...:   0%|          | 0/200 [00:00<?, ?it/s]
# ...
